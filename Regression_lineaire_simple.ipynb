# %%
#question 1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#question 2
# Remplacer 'votre_fichier.csv' par le nom réel du fichier
dataset = pd.read_csv('/content/Salary_dataset.csv')

# %%
#3
# Définir les variables X et y
X = dataset['YearsExperience']
y = dataset['Salary']

# %%
#4
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes
# None

# %%
#5
print(dataset.columns)
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
#6
print(dataset.head(10))
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0

# %%
#7
print(dataset.describe())
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
#8
corr_matrix = dataset.corr()
print(corr_matrix)
# Out:
#                  Unnamed: 0  YearsExperience    Salary
# Unnamed: 0         1.000000         0.986460  0.960826
# YearsExperience    0.986460         1.000000  0.978242
# Salary             0.960826         0.978242  1.000000

# %%
#9
# Avec Matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(corr_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr_matrix)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix)), corr_matrix.columns)
plt.show()

# Avec Seaborn
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
#10
# Variables déjà définies ci-dessus
X = dataset['YearsExperience']
y = dataset['Salary']
plt.scatter(X, y)
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
#11
from scipy import stats


slope, intercept, r_value, p_value, std_err = stats.linregress(X, y)
print(f"Slope: {slope}, Intercept: {intercept}, R-squared: {r_value**2}, P-value: {p_value}, Standard Error: {std_err}")

plt.scatter(X, y)
plt.plot(X, intercept + slope * X, 'r')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()


print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"Standard Error: {std_err}")
# Out:
# Slope: 9449.962321455077, Intercept: 24848.203966523193, R-squared: 0.9569566641435084, P-value: 1.1430681092271558e-20, Standard Error: 378.7545742388215
# Slope: 9449.962321455077
# Intercept: 24848.203966523193
# Standard Error: 378.7545742388215

# %%
#12
from sklearn.linear_model import LinearRegression


#13
# Initialiser et entraîner le modèle
model = LinearRegression()
# Reshape X to be a 2D array
X_reshaped = X.values.reshape(-1, 1)  # Reshape to a column vector
model.fit(X_reshaped, y)
# Out:
# LinearRegression()

# %%
#14
# Faire des prédictions
predictions = model.predict(X_reshaped)

# %%
#15
# Afficher les coefficients
print(f"Coefficient: {model.coef_}")
print(f"Intercept: {model.intercept_}")
# Out:
# Coefficient: [9449.96232146]
# Intercept: 24848.203966523193
